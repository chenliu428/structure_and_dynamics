# %% [markdown]
# # Draw the propensity map

# %%
# %run PyCode/particle_clustering.py

# %%
# %run PyCode/GaussianLH_Panelty_RidgeLasso_MAP.py
# Out:
# GaussianLH_Panelty_RidgeLasso_MAP.py
# item: ridge
# item: lasso
# item: debias
# optimal hyper-parameters:
# ridge : idx = 21, value = 1.28E+02
# lasso : idx = 0, value = 1.00E+01
# debias : idx = 24, value = 5.60E+01

# %%
# %run PyCode/GaussianLH_Panelty_Ridge_Bayes.py
# Out:
# GaussianLH_Penalty_Ridge_Bayes.py
# Number of total data points N :  440
# Number of features M:  96
# Random_Splits:
# 0-th segment: fit --  (396, 96) (396,)  valid --  (44, 96) (44,)
# 1-th segment: fit --  (396, 96) (396,)  valid --  (44, 96) (44,)
# 2-th segment: fit --  (396, 96) (396,)  valid --  (44, 96) (44,)
# 3-th segment: fit --  (396, 96) (396,)  valid --  (44, 96) (44,)
# 4-th segment: fit --  (396, 96) (396,)  valid --  (44, 96) (44,)
# Training Bayes Ridge ...
# Trial: 0
# Trial: 1
# Trial: 2
# Trial: 3
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Trial: 4

# %%
# %run PyCode/Pytorch_study3.py
# Out:
# Pytorch_study3.py
# Number of total data points N :  440
# Number of features M:  96
# Random_Splits:
# 0-th segment: fit --  (352, 96) (352,)  valid --  (88, 96) (88,)
# Ridge MAP usual
# idx_pnlt 0 / 21, idx_cell 0 / 1
# idx_pnlt 1 / 21, idx_cell 0 / 1
# idx_pnlt 2 / 21, idx_cell 0 / 1
# idx_pnlt 3 / 21, idx_cell 0 / 1
# idx_pnlt 4 / 21, idx_cell 0 / 1
# idx_pnlt 5 / 21, idx_cell 0 / 1
# idx_pnlt 6 / 21, idx_cell 0 / 1
# idx_pnlt 7 / 21, idx_cell 0 / 1
# idx_pnlt 8 / 21, idx_cell 0 / 1
# idx_pnlt 9 / 21, idx_cell 0 / 1
# idx_pnlt 10 / 21, idx_cell 0 / 1
# idx_pnlt 11 / 21, idx_cell 0 / 1
# idx_pnlt 12 / 21, idx_cell 0 / 1
# idx_pnlt 13 / 21, idx_cell 0 / 1
# idx_pnlt 14 / 21, idx_cell 0 / 1
# idx_pnlt 15 / 21, idx_cell 0 / 1
# idx_pnlt 16 / 21, idx_cell 0 / 1
# idx_pnlt 17 / 21, idx_cell 0 / 1
# idx_pnlt 18 / 21, idx_cell 0 / 1
# idx_pnlt 19 / 21, idx_cell 0 / 1
# idx_pnlt 20 / 21, idx_cell 0 / 1
# optimal idx:  18
# Epoch.0/10000, Loss.1.00818713E+05, min_err. t.1.00818713E+05, v.7.43502156E+04, lag.0 /3000
# Epoch.200/10000, Loss.4.94319555E-01, min_err. t.4.94319555E-01, v.5.23141113E-01, lag.4 /3000
# Epoch.400/10000, Loss.4.13635220E-01, min_err. t.4.09479921E-01, v.5.16557068E-01, lag.11 /3000
# Epoch.600/10000, Loss.5.45457486E-01, min_err. t.3.83173804E-01, v.5.05132244E-01, lag.14 /3000
# Epoch.800/10000, Loss.6.21083068E-01, min_err. t.3.76388132E-01, v.5.01223872E-01, lag.17 /3000
# Epoch.1000/10000, Loss.5.17267856E-01, min_err. t.3.75814899E-01, v.4.98213830E-01, lag.117 /3000
# Epoch.1200/10000, Loss.4.43237509E-01, min_err. t.3.71368275E-01, v.4.98213830E-01, lag.317 /3000
# Epoch.1400/10000, Loss.6.76257402E-01, min_err. t.3.70637532E-01, v.4.98213830E-01, lag.517 /3000
# Epoch.1600/10000, Loss.4.15852973E-01, min_err. t.3.58464930E-01, v.4.90145819E-01, lag.8 /3000
# Epoch.1800/10000, Loss.7.67695749E-01, min_err. t.3.05352906E-01, v.4.18112744E-01, lag.31 /3000
# Epoch.2000/10000, Loss.4.00519580E-01, min_err. t.3.05352906E-01, v.4.18112744E-01, lag.231 /3000
# Epoch.2200/10000, Loss.3.94710000E-01, min_err. t.3.05352906E-01, v.4.18112744E-01, lag.431 /3000
# Epoch.2400/10000, Loss.2.79721178E-01, min_err. t.2.78907495E-01, v.3.81512799E-01, lag.0 /3000
# Epoch.2600/10000, Loss.2.75583001E-01, min_err. t.2.46795197E-01, v.3.12876239E-01, lag.8 /3000
# Epoch.2800/10000, Loss.2.90679215E-01, min_err. t.2.35065850E-01, v.2.82446214E-01, lag.2 /3000
# Epoch.3000/10000, Loss.2.57157309E-01, min_err. t.2.31887625E-01, v.2.77091974E-01, lag.45 /3000
# Epoch.3200/10000, Loss.2.26448850E-01, min_err. t.2.26023168E-01, v.2.75261339E-01, lag.172 /3000
# Epoch.3400/10000, Loss.2.49718722E-01, min_err. t.2.22419259E-01, v.2.73168406E-01, lag.7 /3000
# Epoch.3600/10000, Loss.2.74758683E-01, min_err. t.2.18162738E-01, v.2.65507263E-01, lag.21 /3000
# Epoch.3800/10000, Loss.2.72128225E-01, min_err. t.2.18162738E-01, v.2.61794532E-01, lag.8 /3000
# Epoch.4000/10000, Loss.2.27596982E-01, min_err. t.2.18162738E-01, v.2.61794532E-01, lag.208 /3000
# Epoch.4200/10000, Loss.2.22365874E-01, min_err. t.2.18162738E-01, v.2.60793689E-01, lag.33 /3000
# Epoch.4400/10000, Loss.2.28083786E-01, min_err. t.2.17746017E-01, v.2.58830168E-01, lag.148 /3000
# Epoch.4600/10000, Loss.2.49050762E-01, min_err. t.2.16655804E-01, v.2.58588825E-01, lag.92 /3000
# Epoch.4800/10000, Loss.2.19581671E-01, min_err. t.2.14441820E-01, v.2.55760184E-01, lag.98 /3000
# Epoch.5000/10000, Loss.2.39894661E-01, min_err. t.2.14441820E-01, v.2.55760184E-01, lag.298 /3000
# Epoch.5200/10000, Loss.2.37274071E-01, min_err. t.2.14252003E-01, v.2.53486687E-01, lag.35 /3000
# Epoch.5400/10000, Loss.2.14691796E-01, min_err. t.2.12379089E-01, v.2.53486687E-01, lag.235 /3000
# Epoch.5600/10000, Loss.2.42425943E-01, min_err. t.2.12117339E-01, v.2.53486687E-01, lag.435 /3000
# Epoch.5800/10000, Loss.2.15172048E-01, min_err. t.2.12117339E-01, v.2.53486687E-01, lag.635 /3000
# Epoch.6000/10000, Loss.2.28732301E-01, min_err. t.2.11438290E-01, v.2.52681196E-01, lag.22 /3000
# Epoch.6200/10000, Loss.2.21671036E-01, min_err. t.2.10773760E-01, v.2.52258657E-01, lag.164 /3000
# Epoch.6400/10000, Loss.2.34280595E-01, min_err. t.2.07101501E-01, v.2.52258657E-01, lag.364 /3000
# Epoch.6600/10000, Loss.2.10615388E-01, min_err. t.2.07101501E-01, v.2.52258657E-01, lag.564 /3000
# Epoch.6800/10000, Loss.2.18545984E-01, min_err. t.2.07101501E-01, v.2.52258657E-01, lag.764 /3000
# Epoch.7000/10000, Loss.3.14191014E-01, min_err. t.2.06906359E-01, v.2.52258657E-01, lag.964 /3000
# Epoch.7200/10000, Loss.2.06493560E-01, min_err. t.2.06241211E-01, v.2.52258657E-01, lag.1164 /3000
# Epoch.7400/10000, Loss.2.46585634E-01, min_err. t.2.03336569E-01, v.2.52258657E-01, lag.1364 /3000
# Epoch.7600/10000, Loss.2.25469011E-01, min_err. t.2.01015803E-01, v.2.52258657E-01, lag.1564 /3000
# Epoch.7800/10000, Loss.2.04276165E-01, min_err. t.2.00733888E-01, v.2.51952231E-01, lag.130 /3000
# Epoch.8000/10000, Loss.2.10795963E-01, min_err. t.1.98860488E-01, v.2.51952231E-01, lag.330 /3000
# Epoch.8200/10000, Loss.2.02337671E-01, min_err. t.1.97903612E-01, v.2.51952231E-01, lag.530 /3000
# Epoch.8400/10000, Loss.2.00778748E-01, min_err. t.1.97903612E-01, v.2.51952231E-01, lag.730 /3000
# Epoch.8600/10000, Loss.2.02773165E-01, min_err. t.1.97525897E-01, v.2.51145631E-01, lag.138 /3000
# Epoch.8800/10000, Loss.1.96836142E-01, min_err. t.1.96762764E-01, v.2.51145631E-01, lag.338 /3000
# Epoch.9000/10000, Loss.1.96866417E-01, min_err. t.1.96380890E-01, v.2.51145631E-01, lag.538 /3000
# Epoch.9200/10000, Loss.2.04117160E-01, min_err. t.1.95694417E-01, v.2.51145631E-01, lag.738 /3000
# Epoch.9400/10000, Loss.2.04113845E-01, min_err. t.1.94068901E-01, v.2.51145631E-01, lag.938 /3000
# Epoch.9600/10000, Loss.1.97652572E-01, min_err. t.1.94068901E-01, v.2.51145631E-01, lag.1138 /3000
# Epoch.9800/10000, Loss.2.16423603E-01, min_err. t.1.92426264E-01, v.2.51145631E-01, lag.1338 /3000
# Epoch: [10000/10000], train_err.2.1482E-01, min_err_trn.1.9129E-01, min_err_vld.2.5115E-01, lag. t.4 & v.1537 / 3000
# restore the best model selections:
# restored min train err: 1.91288279E-01
# restored min valid err: 2.51145631E-01
# stop_state:  reach_wall  epoch.10000/10000, lag.1537/3000!
# Trial.0/1, Valid_Err.2.5115E-01, Train_Err.1.9129E-01, Pearson t/v: 7.1816E-01/7.1402E-01, Stop: reach_wall  epoch.10000/10000, lag.1537/3000! .
