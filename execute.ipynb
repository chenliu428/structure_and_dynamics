# %% [markdown]
# # Working directory
# Run programs from the "project" directory.

# %%
# %%bash
# cd /workspaces/structure_and_dynamics/project
# ls
# Out:
# DATA
# PyCode

# %% [markdown]
# # Draw the propensity map

# %%
# %run PyCode/particle_clustering.py
# Out:
# /workspaces/structure_and_dynamics/project/PyCode/particle_clustering.py:22: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
